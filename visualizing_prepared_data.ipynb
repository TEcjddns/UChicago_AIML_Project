# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('after prep.csv')

overall_rating = df[df['Overall_rating'].notnull()]['Overall_rating']


sns.distplot(df[df['Overall_rating'].notnull()]['Overall_rating'])
overall_rating
# Out:
# C:\Users\jacer\AppData\Local\Temp\ipykernel_10148\1033673556.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Overall_rating'].notnull()]['Overall_rating'])
# 0        4.0
# 1        3.0
# 2        4.0
# 3        1.0
# 4        4.0
#         ...
# 25891    2.0
# 25892    5.0
# 25893    4.0
# 25894    5.0
# 25895    1.0
# Name: Overall_rating, Length: 25896, dtype: float64

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# stacked bar chart of each rating group 1,2,3,4,5
groups = ['Overall_rating', 'work_life_balance', 'skill_development', 'salary_and_benefits']


values1  = []
values2  = []
values3  = []
values4  = []
values5  = []

# for loop over groups
for group in groups:
    values = df[group].groupby(df[group]).count()
    values1.append(values.values[0])
    values2.append(values.values[1])
    values3.append(values.values[2])
    values4.append(values.values[3])
    values5.append(values.values[4])


fig, ax = plt.subplots()

# Stacked bar chart
ax.bar(groups, values1)
ax.bar(groups, values2, bottom = values1)
ax.bar(groups, values3, bottom = values2)
ax.bar(groups, values4, bottom = values3)
ax.bar(groups, values5, bottom = values4)
# Out:
# <BarContainer object of 4 artists>

# %%
import pandas as pd
import numpy as np

rs = np.random.RandomState(0)
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# 'RdBu_r', 'BrBG_r', & PuOr_r are other good diverging colormaps
# Out:
# <style type="text/css">
# #T_a4058_row0_col0, #T_a4058_row1_col1, #T_a4058_row2_col2, #T_a4058_row3_col3, #T_a4058_row4_col4, #T_a4058_row5_col5, #T_a4058_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a4058_row0_col1 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_a4058_row0_col2 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_a4058_row0_col3 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_a4058_row0_col4, #T_a4058_row6_col5 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_a4058_row0_col5, #T_a4058_row3_col0 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_a4058_row0_col6, #T_a4058_row3_col1, #T_a4058_row3_col2, #T_a4058_row3_col4, #T_a4058_row3_col5, #T_a4058_row4_col0, #T_a4058_row4_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a4058_row1_col0 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_a4058_row1_col2 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_a4058_row1_col3 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_a4058_row1_col4 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_a4058_row1_col5, #T_a4058_row2_col6, #T_a4058_row5_col0, #T_a4058_row5_col6 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_a4058_row1_col6 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_a4058_row2_col0 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_a4058_row2_col1 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_a4058_row2_col3, #T_a4058_row6_col4 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_a4058_row2_col4, #T_a4058_row6_col2 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_a4058_row2_col5 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_a4058_row3_col6 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_a4058_row4_col1 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_a4058_row4_col2 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_a4058_row4_col5 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_a4058_row4_col6 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_a4058_row5_col1 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_a4058_row5_col2 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_a4058_row5_col3 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_a4058_row5_col4 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_a4058_row6_col0 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_a4058_row6_col1 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_a4058_row6_col3 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# </style>
# <table id="T_a4058">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a4058_level0_col0" class="col_heading level0 col0" >Overall_rating</th>
#       <th id="T_a4058_level0_col1" class="col_heading level0 col1" >work_life_balance</th>
#       <th id="T_a4058_level0_col2" class="col_heading level0 col2" >skill_development</th>
#       <th id="T_a4058_level0_col3" class="col_heading level0 col3" >salary_and_benefits</th>
#       <th id="T_a4058_level0_col4" class="col_heading level0 col4" >job_security</th>
#       <th id="T_a4058_level0_col5" class="col_heading level0 col5" >career_growth</th>
#       <th id="T_a4058_level0_col6" class="col_heading level0 col6" >work_satisfaction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4058_level0_row0" class="row_heading level0 row0" >Overall_rating</th>
#       <td id="T_a4058_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_a4058_row0_col1" class="data row0 col1" >0.672291</td>
#       <td id="T_a4058_row0_col2" class="data row0 col2" >0.675048</td>
#       <td id="T_a4058_row0_col3" class="data row0 col3" >0.625899</td>
#       <td id="T_a4058_row0_col4" class="data row0 col4" >0.618375</td>
#       <td id="T_a4058_row0_col5" class="data row0 col5" >0.701959</td>
#       <td id="T_a4058_row0_col6" class="data row0 col6" >0.646073</td>
#     </tr>
#     <tr>
#       <th id="T_a4058_level0_